# %%
from dash import Dash, html, dcc, Input, Output, State
import dash_bootstrap_components as dbc
import pymysql
from sqlalchemy import create_engine, text
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# %%
pro = 'mysql+pymysql://'
user = 'bigdata'
password = 'Bigdata123!!'
host = '192.168.56.101'
port = '3306'
db = 'SampleDB'
engine = create_engine(f'{pro}{user}:{password}@{host}:{port}/{db}')
conn = engine.connect()

# %%
continent = pd.read_sql("select distinct continent from world",conn)
continent = continent.loc[:,"continent"].values
year = pd.read_sql("select distinct year from world",conn)
year = year.loc[:,"year"].values

# %%
sample_bootstrap = "https://cdn.jsdelivr.net/npm/bootstrap@5.1.3/dist/css/bootstrap.min.css"
app = Dash(external_stylesheets=[sample_bootstrap])
app.layout = html.Div(
    [
        dbc.Row(
            [
                html.Div("World Population & GDP",
                        style={"font-size":16,
                               "color":"white",
                               "background-color":"black",
                               "text-align":"center"})
            ]
        ),
        dbc.Row(
            [
                dbc.Col(
                    [
                        html.Label("대륙",
                                   style={"font-size":10}),
                        dcc.Dropdown(id="dropdown1",
                                    options = [{"label":i,"value":i} for i in continent],
                                    placeholder = continent[0],
                                    style={"font-size":10,"height":"5px"})
                    ]
                ),
                dbc.Col(
                    [
                        html.Label("국가",
                                   style={"font-size":10}),
                        html.Div(id="dropdown-result", style={"height":"5px"}),
                    ]
                ),
                dbc.Col(
                    [
                        html.Label("연도",
                                   style={"font-size":10}),
                        dcc.Dropdown(id="dropdown3",
                                    options = [{"label":i,"value":i} for i in year],
                                    placeholder = year[0],
                                    style={"font-size":10,"height":"5px"})
                    ]
                ),
            ]
        ),
        html.P(),
        dbc.Row(
            [
                dbc.Col(
                    dcc.Graph(id='bar-graph')
                ),
                dbc.Col(
                    dcc.Graph(id='pie-graph')
                ),
            ]
        )
    ]
)

# %%
@app.callback(
    Output("dropdown-result",'children'),
    Input('dropdown1','value')
)

def update_country(continent):
    country = pd.read_sql(f"select distinct country from world where continent = '{continent}'",conn)
    country = country.loc[:,"country"].values
    return html.Div(
        [
            dcc.Dropdown(
                id='dropdown2',
                options = [{'label':i, 'value':i} for i in country],
                style = {"font-size":10,'height':'5px'}
            )
        ])

@app.callback(
    Output('bar-graph','figure'),
    Input('dropdown1','value'),
    Input('dropdown2','value'),
    Input('dropdown3','value')
)
def update_bargraph(continent,country,year):
    df = pd.read_sql("select * from world", conn)
    dt = df.loc[(df.continent == continent) & (df.country == country), ['year','gdpPercap']]
    fig = px.bar(x=dt.year.values, y=dt.gdpPercap.values)
    return fig

@app.callback(
    Output('pie-graph','figure'),
    Input('dropdown1','value'),
    Input('dropdown2','value'),
    Input('dropdown3','value')
)
def update_piegraph(continent,country,year):
    df = pd.read_sql("select * from world", conn)
    dt = df.loc[(df.continent == continent) & (df.country == country), ['year','pop']]
    fig = px.pie(names=dt.year.values, values=dt.loc[:,'pop'].values)
    return fig

# %%
app.run_server(host='192.168.56.101',port=5555)
# Out:
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://192.168.56.101:5555/ (Press CTRL+C to quit)
# 192.168.56.1 - - [21/Feb/2022 17:19:38] "GET / HTTP/1.1" 200 -
# 192.168.56.1 - - [21/Feb/2022 17:19:38] "GET /_dash-layout HTTP/1.1" 200 -
# 192.168.56.1 - - [21/Feb/2022 17:19:38] "GET /_dash-dependencies HTTP/1.1" 200 -
# 192.168.56.1 - - [21/Feb/2022 17:19:38] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 192.168.56.1 - - [21/Feb/2022 17:19:38] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 192.168.56.1 - - [21/Feb/2022 17:19:38] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 192.168.56.1 - - [21/Feb/2022 17:19:38] "POST /_dash-update-component HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_4409/2713598435.py", line 27, in update_bargraph
#     fig = px.bar(x=dt.year.values, y=dt.gdpPercap.values)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_chart_types.py", line 368, in bar
#     return make_figure(
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1945, in make_figure
#     args = build_dataframe(args, constructor)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1324, in build_dataframe
#     raise ValueError(
# ValueError: Cannot accept list of column references or list of columns for both `x` and `y`.
# 192.168.56.1 - - [21/Feb/2022 17:19:38] "POST /_dash-update-component HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_4409/2713598435.py", line 27, in update_bargraph
#     fig = px.bar(x=dt.year.values, y=dt.gdpPercap.values)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_chart_types.py", line 368, in bar
#     return make_figure(
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1945, in make_figure
#     args = build_dataframe(args, constructor)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1324, in build_dataframe
#     raise ValueError(
# ValueError: Cannot accept list of column references or list of columns for both `x` and `y`.
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_4409/2713598435.py", line 27, in update_bargraph
#     fig = px.bar(x=dt.year.values, y=dt.gdpPercap.values)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_chart_types.py", line 368, in bar
#     return make_figure(
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1945, in make_figure
#     args = build_dataframe(args, constructor)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1324, in build_dataframe
#     raise ValueError(
# ValueError: Cannot accept list of column references or list of columns for both `x` and `y`.
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_4409/2713598435.py", line 27, in update_bargraph
#     fig = px.bar(x=dt.year.values, y=dt.gdpPercap.values)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_chart_types.py", line 368, in bar
#     return make_figure(
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1945, in make_figure
#     args = build_dataframe(args, constructor)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1324, in build_dataframe
#     raise ValueError(
# ValueError: Cannot accept list of column references or list of columns for both `x` and `y`.
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_4409/2713598435.py", line 27, in update_bargraph
#     fig = px.bar(x=dt.year.values, y=dt.gdpPercap.values)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_chart_types.py", line 368, in bar
#     return make_figure(
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1945, in make_figure
#     args = build_dataframe(args, constructor)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1324, in build_dataframe
#     raise ValueError(
# ValueError: Cannot accept list of column references or list of columns for both `x` and `y`.
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_4409/2713598435.py", line 27, in update_bargraph
#     fig = px.bar(x=dt.year.values, y=dt.gdpPercap.values)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_chart_types.py", line 368, in bar
#     return make_figure(
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1945, in make_figure
#     args = build_dataframe(args, constructor)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1324, in build_dataframe
#     raise ValueError(
# ValueError: Cannot accept list of column references or list of columns for both `x` and `y`.
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_4409/2713598435.py", line 27, in update_bargraph
#     fig = px.bar(x=dt.year.values, y=dt.gdpPercap.values)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_chart_types.py", line 368, in bar
#     return make_figure(
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1945, in make_figure
#     args = build_dataframe(args, constructor)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1324, in build_dataframe
#     raise ValueError(
# ValueError: Cannot accept list of column references or list of columns for both `x` and `y`.
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_4409/2713598435.py", line 27, in update_bargraph
#     fig = px.bar(x=dt.year.values, y=dt.gdpPercap.values)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_chart_types.py", line 368, in bar
#     return make_figure(
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1945, in make_figure
#     args = build_dataframe(args, constructor)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1324, in build_dataframe
#     raise ValueError(
# ValueError: Cannot accept list of column references or list of columns for both `x` and `y`.
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_4409/2713598435.py", line 27, in update_bargraph
#     fig = px.bar(x=dt.year.values, y=dt.gdpPercap.values)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_chart_types.py", line 368, in bar
#     return make_figure(
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1945, in make_figure
#     args = build_dataframe(args, constructor)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1324, in build_dataframe
#     raise ValueError(
# ValueError: Cannot accept list of column references or list of columns for both `x` and `y`.
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_4409/2713598435.py", line 27, in update_bargraph
#     fig = px.bar(x=dt.year.values, y=dt.gdpPercap.values)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_chart_types.py", line 368, in bar
#     return make_figure(
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1945, in make_figure
#     args = build_dataframe(args, constructor)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1324, in build_dataframe
#     raise ValueError(
# ValueError: Cannot accept list of column references or list of columns for both `x` and `y`.
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_4409/2713598435.py", line 27, in update_bargraph
#     fig = px.bar(x=dt.year.values, y=dt.gdpPercap.values)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_chart_types.py", line 368, in bar
#     return make_figure(
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1945, in make_figure
#     args = build_dataframe(args, constructor)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1324, in build_dataframe
#     raise ValueError(
# ValueError: Cannot accept list of column references or list of columns for both `x` and `y`.
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_4409/2713598435.py", line 27, in update_bargraph
#     fig = px.bar(x=dt.year.values, y=dt.gdpPercap.values)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_chart_types.py", line 368, in bar
#     return make_figure(
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1945, in make_figure
#     args = build_dataframe(args, constructor)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1324, in build_dataframe
#     raise ValueError(
# ValueError: Cannot accept list of column references or list of columns for both `x` and `y`.
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_4409/2713598435.py", line 27, in update_bargraph
#     fig = px.bar(x=dt.year.values, y=dt.gdpPercap.values)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_chart_types.py", line 368, in bar
#     return make_figure(
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1945, in make_figure
#     args = build_dataframe(args, constructor)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1324, in build_dataframe
#     raise ValueError(
# ValueError: Cannot accept list of column references or list of columns for both `x` and `y`.
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_4409/2713598435.py", line 27, in update_bargraph
#     fig = px.bar(x=dt.year.values, y=dt.gdpPercap.values)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_chart_types.py", line 368, in bar
#     return make_figure(
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1945, in make_figure
#     args = build_dataframe(args, constructor)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1324, in build_dataframe
#     raise ValueError(
# ValueError: Cannot accept list of column references or list of columns for both `x` and `y`.
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_4409/2713598435.py", line 27, in update_bargraph
#     fig = px.bar(x=dt.year.values, y=dt.gdpPercap.values)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_chart_types.py", line 368, in bar
#     return make_figure(
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1945, in make_figure
#     args = build_dataframe(args, constructor)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1324, in build_dataframe
#     raise ValueError(
# ValueError: Cannot accept list of column references or list of columns for both `x` and `y`.
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_4409/2713598435.py", line 27, in update_bargraph
#     fig = px.bar(x=dt.year.values, y=dt.gdpPercap.values)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_chart_types.py", line 368, in bar
#     return make_figure(
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1945, in make_figure
#     args = build_dataframe(args, constructor)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1324, in build_dataframe
#     raise ValueError(
# ValueError: Cannot accept list of column references or list of columns for both `x` and `y`.
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_4409/2713598435.py", line 27, in update_bargraph
#     fig = px.bar(x=dt.year.values, y=dt.gdpPercap.values)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_chart_types.py", line 368, in bar
#     return make_figure(
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1945, in make_figure
#     args = build_dataframe(args, constructor)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1324, in build_dataframe
#     raise ValueError(
# ValueError: Cannot accept list of column references or list of columns for both `x` and `y`.
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_4409/2713598435.py", line 27, in update_bargraph
#     fig = px.bar(x=dt.year.values, y=dt.gdpPercap.values)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_chart_types.py", line 368, in bar
#     return make_figure(
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1945, in make_figure
#     args = build_dataframe(args, constructor)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1324, in build_dataframe
#     raise ValueError(
# ValueError: Cannot accept list of column references or list of columns for both `x` and `y`.
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_4409/2713598435.py", line 27, in update_bargraph
#     fig = px.bar(x=dt.year.values, y=dt.gdpPercap.values)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_chart_types.py", line 368, in bar
#     return make_figure(
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1945, in make_figure
#     args = build_dataframe(args, constructor)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1324, in build_dataframe
#     raise ValueError(
# ValueError: Cannot accept list of column references or list of columns for both `x` and `y`.
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_4409/2713598435.py", line 27, in update_bargraph
#     fig = px.bar(x=dt.year.values, y=dt.gdpPercap.values)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_chart_types.py", line 368, in bar
#     return make_figure(
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1945, in make_figure
#     args = build_dataframe(args, constructor)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1324, in build_dataframe
#     raise ValueError(
# ValueError: Cannot accept list of column references or list of columns for both `x` and `y`.
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_4409/2713598435.py", line 27, in update_bargraph
#     fig = px.bar(x=dt.year.values, y=dt.gdpPercap.values)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_chart_types.py", line 368, in bar
#     return make_figure(
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1945, in make_figure
#     args = build_dataframe(args, constructor)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1324, in build_dataframe
#     raise ValueError(
# ValueError: Cannot accept list of column references or list of columns for both `x` and `y`.
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_4409/2713598435.py", line 27, in update_bargraph
#     fig = px.bar(x=dt.year.values, y=dt.gdpPercap.values)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_chart_types.py", line 368, in bar
#     return make_figure(
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1945, in make_figure
#     args = build_dataframe(args, constructor)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1324, in build_dataframe
#     raise ValueError(
# ValueError: Cannot accept list of column references or list of columns for both `x` and `y`.
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_4409/2713598435.py", line 27, in update_bargraph
#     fig = px.bar(x=dt.year.values, y=dt.gdpPercap.values)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_chart_types.py", line 368, in bar
#     return make_figure(
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1945, in make_figure
#     args = build_dataframe(args, constructor)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1324, in build_dataframe
#     raise ValueError(
# ValueError: Cannot accept list of column references or list of columns for both `x` and `y`.
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
# ...
#     raise ValueError(
# ValueError: Cannot accept list of column references or list of columns for both `x` and `y`.
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_4409/2713598435.py", line 27, in update_bargraph
#     fig = px.bar(x=dt.year.values, y=dt.gdpPercap.values)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_chart_types.py", line 368, in bar
#     return make_figure(
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1945, in make_figure
#     args = build_dataframe(args, constructor)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1324, in build_dataframe
#     raise ValueError(
# ValueError: Cannot accept list of column references or list of columns for both `x` and `y`.
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_4409/2713598435.py", line 27, in update_bargraph
#     fig = px.bar(x=dt.year.values, y=dt.gdpPercap.values)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_chart_types.py", line 368, in bar
#     return make_figure(
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1945, in make_figure
#     args = build_dataframe(args, constructor)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1324, in build_dataframe
#     raise ValueError(
# ValueError: Cannot accept list of column references or list of columns for both `x` and `y`.
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_4409/2713598435.py", line 27, in update_bargraph
#     fig = px.bar(x=dt.year.values, y=dt.gdpPercap.values)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_chart_types.py", line 368, in bar
#     return make_figure(
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1945, in make_figure
#     args = build_dataframe(args, constructor)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1324, in build_dataframe
#     raise ValueError(
# ValueError: Cannot accept list of column references or list of columns for both `x` and `y`.
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_4409/2713598435.py", line 27, in update_bargraph
#     fig = px.bar(x=dt.year.values, y=dt.gdpPercap.values)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_chart_types.py", line 368, in bar
#     return make_figure(
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1945, in make_figure
#     args = build_dataframe(args, constructor)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1324, in build_dataframe
#     raise ValueError(
# ValueError: Cannot accept list of column references or list of columns for both `x` and `y`.
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_4409/2713598435.py", line 27, in update_bargraph
#     fig = px.bar(x=dt.year.values, y=dt.gdpPercap.values)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_chart_types.py", line 368, in bar
#     return make_figure(
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1945, in make_figure
#     args = build_dataframe(args, constructor)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1324, in build_dataframe
#     raise ValueError(
# ValueError: Cannot accept list of column references or list of columns for both `x` and `y`.
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_4409/2713598435.py", line 27, in update_bargraph
#     fig = px.bar(x=dt.year.values, y=dt.gdpPercap.values)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_chart_types.py", line 368, in bar
#     return make_figure(
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1945, in make_figure
#     args = build_dataframe(args, constructor)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1324, in build_dataframe
#     raise ValueError(
# ValueError: Cannot accept list of column references or list of columns for both `x` and `y`.
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_4409/2713598435.py", line 27, in update_bargraph
#     fig = px.bar(x=dt.year.values, y=dt.gdpPercap.values)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_chart_types.py", line 368, in bar
#     return make_figure(
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1945, in make_figure
#     args = build_dataframe(args, constructor)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1324, in build_dataframe
#     raise ValueError(
# ValueError: Cannot accept list of column references or list of columns for both `x` and `y`.
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_4409/2713598435.py", line 27, in update_bargraph
#     fig = px.bar(x=dt.year.values, y=dt.gdpPercap.values)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_chart_types.py", line 368, in bar
#     return make_figure(
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1945, in make_figure
#     args = build_dataframe(args, constructor)
#   File "/home/ejchoi/anaconda3/lib/python3.9/site-packages/plotly/express/_core.py", line 1324, in build_dataframe
#     raise ValueError(
# ValueError: Cannot accept list of column references or list of columns for both `x` and `y`.
# 192.168.56.1 - - [21/Feb/2022 17:19:41] "POST /_dash-update-component HTTP/1.1" 500 -
# 192.168.56.1 - - [21/Feb/2022 17:19:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.56.1 - - [21/Feb/2022 17:19:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.56.1 - - [21/Feb/2022 17:19:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.56.1 - - [21/Feb/2022 17:19:46] "POST /_dash-update-component HTTP/1.1" 200 -
