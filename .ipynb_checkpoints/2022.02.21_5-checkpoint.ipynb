# %%
from dash import Dash, html, dcc, Input, Output, State
import dash_bootstrap_components as dbc
import pymysql
from sqlalchemy import create_engine, text
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# %%
pro = 'mysql+pymysql://'
user = 'bigdata'
password = 'Bigdata123!!'
host = '192.168.56.101'
port = '3306'
db = 'SampleDB'
engine = create_engine(f'{pro}{user}:{password}@{host}:{port}/{db}')
conn = engine.connect()

# %%
continent = pd.read_sql("select distinct continent from world",conn)
continent = continent.loc[:,"continent"].values
year = pd.read_sql("select distinct year from world",conn)
year = year.loc[:,"year"].values

# %%
sample_bootstrap = "https://cdn.jsdelivr.net/npm/bootstrap@5.1.3/dist/css/bootstrap.min.css"
app = Dash(external_stylesheets=[sample_bootstrap])
app.layout = html.Div(
    [
        dbc.Row(
            [
                html.Div("World Population & GDP",
                        style={"font-size":16,
                               "color":"white",
                               "background-color":"black",
                               "text-align":"center"})
            ]
        ),
        dbc.Row(
            [
                dbc.Col(
                    [
                        html.Label("대륙",
                                   style={"font-size":10}),
                        dcc.Dropdown(id="dropdown1",
                                    options = [{"label":i, "value":i} for i in continent],
                                    placeholder = continent[0],
                                    style = {"font-size":10,"height":"5px"}
                                    ),
                    ]
                ),
                dbc.Col(
                    [
                        html.Label("국가",
                                   style={"font-size":10}),
                        html.Div(id="dropdown-result", style={"height":"5px"}),
                    ]
                ),
                dbc.Col(
                    [
                        html.Label("연도",
                                   style={"font-size":10}),
                        dcc.Dropdown(id="dropdown3",
                                    options = [{"label":i,"value":i} for i in year],
                                    placeholder = year[0],
                                    style={"font-size":10,"height":"5px"})
                    ]
                ),
            ]
        ),
        html.P(),
        html.Hr(),
        dbc.Row(
            [
                dbc.Col(
                    dcc.Graph(id='bar-graph')
                ),
                dbc.Col(
                    dcc.Graph(id='pie-graph')
                ),
            ]
        )
    ]
)

# %%
@app.callback(
    Output("dropdown-result",'children'),
    Input('dropdown1','value')
)

def update_country(continent):
    country = pd.read_sql(f"select distinct country from world where continent = '{continent}'",conn)
    country = country.loc[:,"country"].values
    return html.Div(
        [
            dcc.Dropdown(
                id='dropdown2',
                options = [{'label':i, 'value':i} for i in country],
                style = {"font-size":10,'height':'5px'}
            )
        ])

@app.callback(
    Output(,),
    Input(,),
    Input(,),
    Input(,)
)
def update_bargraph():
    

@app.callback(
    Output(,),
    Input(,),
    Input(,),
    Input(,)
)
def update_piegraph():

# %%
app.run_server(host='192.168.56.101',port=5555)
# Out:
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://192.168.56.101:5555/ (Press CTRL+C to quit)
# 192.168.56.1 - - [21/Feb/2022 16:41:41] "GET / HTTP/1.1" 200 -
# 192.168.56.1 - - [21/Feb/2022 16:41:41] "GET /_dash-layout HTTP/1.1" 200 -
# 192.168.56.1 - - [21/Feb/2022 16:41:41] "GET /_dash-dependencies HTTP/1.1" 200 -
# 192.168.56.1 - - [21/Feb/2022 16:41:41] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 192.168.56.1 - - [21/Feb/2022 16:41:41] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 192.168.56.1 - - [21/Feb/2022 16:41:41] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 192.168.56.1 - - [21/Feb/2022 16:41:41] "POST /_dash-update-component HTTP/1.1" 200 -
