# %%
## 필요한 모듈 임포트
from dash import Dash, html, dcc, Input, Output, State
import pandas as pd
import plotly.express as px

from sqlalchemy import create_engine, text
import pymysql

# %%
## 데이터 정리
# DB접속
user = 'bigdata'
password = 'Bigdata123!!'
host = '192.168.56.101'
port = '3306'
db = 'SampleDB'
engine = create_engine(f'mysql+pymysql://{user}:{password}@{host}:{port}/{db}')
conn = engine.connect()
world = pd.read_sql('select * from world', conn)

# %%
## app구현 -프론트엔드
web_service = Dash(__name__)
web_service.layout = html.Div(
    [
        html.Label('첫번째 값을 입력하세요 '),
        dcc.Input(id='input-1',
                 type = 'text'),
        html.Label('두번째 값을 입력하세요 '),
        dcc.Input(id='input-2',
                 type = 'text'),
        html.Button('계산',
                    id="button-1",
                    n_clicks=0),
        # dcc.RadioItems(id='radio-1',
        #               options=['+','-','×','÷'],
        #               value = '+',
        #               inline = True
        #               ),
        html.Hr(),
        html.Div(id='aaaa')
    ]
)

# %%
## app구현 -백엔드
@web_service.callback(
    Output('aaaa','children'),
    Input('button-1','n_clicks'),
    State('input-1','value'),
    State('input-2','value'),
    # State('radio-1','value'),
)
# def xxxx(n,a,b,c):
#     if c == '+':
#         result = int(a)+int(b)
#     elif c == '-':
#         result = int(a)-int(b)
#     elif c == '×':
#         result = int(a)*int(b)
#     else:
#         result = int(a)/int(b)
#     x = html.H1(f"{a} {c} {b}의 결과값은 {result} 입니다")
#     return x

def xxxx(n,a,b):
    x1 = int(a)+int(b)
    x2 = int(a)-int(b)
    x3 = int(a)*int(b)
    x4 = int(a)/int(b)
    return html.Div(
        [
            html.H1(f'더하기는 {x1}'),
            html.H2(f'빼기는 {x2}'),
            html.H3(f'곱하기는 {x3}'),
            html.H4(f'나누기는 {x4}'),
        ])

# %%
## app run
web_service.run_server(host='192.168.56.101', port='7777')
# Out:
# Dash is running on http://192.168.56.101:7777/
#
# Dash is running on http://192.168.56.101:7777/
#
# Dash is running on http://192.168.56.101:7777/
#
# Dash is running on http://192.168.56.101:7777/
#
# Dash is running on http://192.168.56.101:7777/
#
# Dash is running on http://192.168.56.101:7777/
#
# Dash is running on http://192.168.56.101:7777/
#
# Dash is running on http://192.168.56.101:7777/
#
# Dash is running on http://192.168.56.101:7777/
#
# Dash is running on http://192.168.56.101:7777/
#
# Dash is running on http://192.168.56.101:7777/
#
# Dash is running on http://192.168.56.101:7777/
#
# Dash is running on http://192.168.56.101:7777/
#
# Dash is running on http://192.168.56.101:7777/
#
# Dash is running on http://192.168.56.101:7777/
#
# Dash is running on http://192.168.56.101:7777/
#
# Dash is running on http://192.168.56.101:7777/
#
# Dash is running on http://192.168.56.101:7777/
#
# Dash is running on http://192.168.56.101:7777/
#
# ...
